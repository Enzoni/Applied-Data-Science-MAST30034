# %%
import pandas as pd
import numpy as np
from numpy import log, sqrt
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_feather('data/yellow_tripdata_01.feather')
df
# Out:
#          tpep_pickup_datetime tpep_dropoff_datetime  pickup_longitude  \
# 0         2016-01-01 00:00:00   2016-01-01 00:00:00        -73.990372
# 1         2016-01-01 00:00:00   2016-01-01 00:00:00        -73.980782
# 2         2016-01-01 00:00:00   2016-01-01 00:00:00        -73.984550
# 3         2016-01-01 00:00:00   2016-01-01 00:00:00        -73.993469
# 4         2016-01-01 00:00:00   2016-01-01 00:00:00        -73.960625
# ...                       ...                   ...               ...
# 10906853  2016-01-31 23:30:32   2016-01-31 23:38:18        -74.003578
# 10906854  2016-01-05 00:15:55   2016-01-05 00:16:06        -73.945488
# 10906855  2016-01-05 06:12:46   2016-03-19 20:45:50        -73.994240
# 10906856  2016-01-05 06:21:44   2016-03-28 12:54:26        -73.948067
# 10906857  2016-01-05 06:15:21   2016-01-05 06:15:36        -73.960938
#
#           pickup_latitude  dropoff_longitude  dropoff_latitude  tolls_amount  \
# ...

# %%
df["duration"] = df["duration"] / 60

# %%
df = df.loc[(df["duration"] >= 0.5) & (df["total_amount"]>0)
            & (df["income"] > 0)]

# %%
fig, ax = plt.subplots(1, 3) 
  
sns.distplot(df['duration'], hist = False, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "duration", color ="blue", ax = ax[0]) 
  
sns.distplot(df['total_amount'], hist = False, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "total_amount", color ="blue", ax = ax[1]) 

sns.distplot(df['income'], hist = False, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "income", color ="blue", ax = ax[2]) 
  
plt.legend(loc = "upper right") 
fig.set_figheight(5) 
fig.set_figwidth(10) 
fig.set_figwidth(15)

# %%
df = df.loc[(df["duration"] <= 200) & (df["total_amount"]<=20000)
            & (df["income"] <=30000)]

# %%
fig, ax = plt.subplots(1, 3) 
  
sns.distplot(df['duration'], hist = False, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "duration", color ="blue", ax = ax[0]) 
  
sns.distplot(df['total_amount'], hist = False, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "total_amount", color ="blue", ax = ax[1]) 

sns.distplot(df['income'], hist = False, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "income", color ="blue", ax = ax[2]) 
  
plt.legend(loc = "upper right") 
fig.set_figheight(5) 
fig.set_figwidth(10) 
fig.set_figwidth(15)

# %%
df = df.loc[(df["duration"] <= 150) & (df["total_amount"]<=150)
            & (df["income"] <=150)]

# %%
fig, ax = plt.subplots(1, 3) 
  
sns.distplot(df['duration'], hist = False, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "duration", color ="blue", ax = ax[0]) 
  
sns.distplot(df['total_amount'], hist = False, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "total_amount", color ="blue", ax = ax[1]) 

sns.distplot(df['income'], hist = False, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "income", color ="blue", ax = ax[2]) 
  
plt.legend(loc = "upper right") 
fig.set_figheight(5) 
fig.set_figwidth(10) 
fig.set_figwidth(15)

# %%
df
# Out:
#          tpep_pickup_datetime tpep_dropoff_datetime  pickup_longitude  \
# 5         2016-01-01 00:00:00   2016-01-01 00:18:30        -73.980118
# 6         2016-01-01 00:00:00   2016-01-01 00:26:45        -73.994057
# 7         2016-01-01 00:00:01   2016-01-01 00:11:55        -73.979424
# 8         2016-01-01 00:00:02   2016-01-01 00:11:14        -73.947151
# 9         2016-01-01 00:00:02   2016-01-01 00:11:08        -73.998344
# ...                       ...                   ...               ...
# 10906849  2016-01-31 21:28:59   2016-01-31 22:01:58        -74.002953
# 10906850  2016-01-31 22:36:41   2016-01-31 22:45:04        -74.009277
# 10906851  2016-01-31 22:53:00   2016-01-31 22:59:37        -74.003578
# 10906852  2016-01-31 23:00:11   2016-01-31 23:12:08        -74.002159
# 10906853  2016-01-31 23:30:32   2016-01-31 23:38:18        -74.003578
#
#           pickup_latitude  dropoff_longitude  dropoff_latitude  tolls_amount  \
# ...

# %%
df.reset_index(inplace=True, drop=True)
df
# Out:
#          tpep_pickup_datetime tpep_dropoff_datetime  pickup_longitude  \
# 0         2016-01-01 00:00:00   2016-01-01 00:18:30        -73.980118
# 1         2016-01-01 00:00:00   2016-01-01 00:26:45        -73.994057
# 2         2016-01-01 00:00:01   2016-01-01 00:11:55        -73.979424
# 3         2016-01-01 00:00:02   2016-01-01 00:11:14        -73.947151
# 4         2016-01-01 00:00:02   2016-01-01 00:11:08        -73.998344
# ...                       ...                   ...               ...
# 10824140  2016-01-31 21:28:59   2016-01-31 22:01:58        -74.002953
# 10824141  2016-01-31 22:36:41   2016-01-31 22:45:04        -74.009277
# 10824142  2016-01-31 22:53:00   2016-01-31 22:59:37        -74.003578
# 10824143  2016-01-31 23:00:11   2016-01-31 23:12:08        -74.002159
# 10824144  2016-01-31 23:30:32   2016-01-31 23:38:18        -74.003578
#
#           pickup_latitude  dropoff_longitude  dropoff_latitude  tolls_amount  \
# ...

# %%
df.to_feather('data/yellow_tripdata_01.feather')
