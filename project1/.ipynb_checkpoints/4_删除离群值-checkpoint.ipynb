# %%
import pandas as pd
import numpy as np
from numpy import log, sqrt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_feather('data/yellow_tripdata_01.feather')
df
# Out:
#          tpep_pickup_datetime tpep_dropoff_datetime  pickup_longitude  \
# 0         2016-01-01 00:00:00   2016-01-01 00:00:00        -73.990372
# 1         2016-01-01 00:00:00   2016-01-01 00:00:00        -73.980782
# 2         2016-01-01 00:00:00   2016-01-01 00:00:00        -73.984550
# 3         2016-01-01 00:00:00   2016-01-01 00:00:00        -73.993469
# 4         2016-01-01 00:00:00   2016-01-01 00:00:00        -73.960625
# ...                       ...                   ...               ...
# 10906853  2016-01-31 23:30:32   2016-01-31 23:38:18        -74.003578
# 10906854  2016-01-05 00:15:55   2016-01-05 00:16:06        -73.945488
# 10906855  2016-01-05 06:12:46   2016-03-19 20:45:50        -73.994240
# 10906856  2016-01-05 06:21:44   2016-03-28 12:54:26        -73.948067
# 10906857  2016-01-05 06:15:21   2016-01-05 06:15:36        -73.960938
#
#           pickup_latitude  dropoff_longitude  dropoff_latitude  tolls_amount  \
# ...

# %%
sns.distplot(df['income'].apply(lambda x: log(x) if x else 0), bins=50)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
sns.distplot(df['income'].apply(lambda x: log(x) if x else 0), bins=30)
plt.show()

# %%
df['duration'] = df['duration']/60

# %%
df.describe().loc[['25%','75%']]
# Out:
#      pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 25%        -73.991508        40.736301         -73.991074         40.734806
# 75%        -73.966103        40.768082         -73.961960         40.769619
#
#      tolls_amount  total_amount   duration  start_hour  income     in/du
# 25%           0.0          8.30   6.333333         9.0    8.30  0.016398
# 75%           0.0         17.16  16.883333        19.0   17.16  0.024502

# %%
def find_range(df):
    q1_q3 = df.describe().loc[['25%','75%']]
    step = q1_q3.loc['75%'] - q1_q3.loc['25%'] * 1.5
    print(step)
    q1_q3.loc['25%']  =  q1_q3.loc['25%'] - step
    q1_q3.loc['75%'] = q1_q3.loc['75%'] + step
    return q1_q3

# %%
acc_range = find_range(df)
acc_range
# Out:
# pickup_longitude     37.021160
# pickup_latitude     -20.336370
# dropoff_longitude    37.024651
# dropoff_latitude    -20.332590
# tolls_amount          0.000000
# total_amount          4.710000
# duration              7.383333
# start_hour            5.500000
# income                4.710000
# in/du                -0.000096
# dtype: float64
#      pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 25%       -111.012669        61.072672        -111.015724         61.067396
# 75%        -36.944942        20.431711         -36.937309         20.437029
#
#      tolls_amount  total_amount   duration  start_hour  income     in/du
# 25%           0.0          3.59  -1.050000         3.5    3.59  0.016494
# 75%           0.0         21.87  24.266667        24.5   21.87  0.024406

# %%
df_del_duration = df.loc[(df["duration"] >= 0) & (df["duration"] <= 70)]

# %%
sns.distplot(df_del_duration['duration'],kde=False)

plt.show()

# %%
df_del_duration = df.loc[(df["duration"] >= 0.5) & (df["duration"] <= 60)]

# %%
df_total_amount = df_del_duration.loc[
    (df_del_duration["total_amount"] >= 0) &
    (df_del_duration["total_amount"] <= 80) &
    (df_del_duration["income"] >=0)]

# %%
sns.distplot(df_total_amount['income'],kde=False)
plt.show()

# %%
df_total_amount
# Out:
#          tpep_pickup_datetime tpep_dropoff_datetime  pickup_longitude  \
# 5         2016-01-01 00:00:00   2016-01-01 00:18:30        -73.980118
# 6         2016-01-01 00:00:00   2016-01-01 00:26:45        -73.994057
# 7         2016-01-01 00:00:01   2016-01-01 00:11:55        -73.979424
# 8         2016-01-01 00:00:02   2016-01-01 00:11:14        -73.947151
# 9         2016-01-01 00:00:02   2016-01-01 00:11:08        -73.998344
# ...                       ...                   ...               ...
# 10906849  2016-01-31 21:28:59   2016-01-31 22:01:58        -74.002953
# 10906850  2016-01-31 22:36:41   2016-01-31 22:45:04        -74.009277
# 10906851  2016-01-31 22:53:00   2016-01-31 22:59:37        -74.003578
# 10906852  2016-01-31 23:00:11   2016-01-31 23:12:08        -74.002159
# 10906853  2016-01-31 23:30:32   2016-01-31 23:38:18        -74.003578
#
#           pickup_latitude  dropoff_longitude  dropoff_latitude  tolls_amount  \
# ...

# %%
df_total_amount.drop(['tolls_amount','total_amount'],axis=1, inplace=True)
df_total_amount.reset_index(inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_total_amount.to_feather('data/tripdata_with_weather.feather')
